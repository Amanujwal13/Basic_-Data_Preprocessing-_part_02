# %% [markdown]
# ````

# %% [markdown]
# ``Data Preporcessing``

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ``Data Loading``

# %%
final_df = pd.read_csv('data\\train.csv')
final_df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   name          850 non-null    str
#  3   sex           850 non-null    str
#  4   age           676 non-null    float64
#  5   sibsp         850 non-null    int64
#  6   parch         850 non-null    int64
#  7   ticket        850 non-null    str
#  8   fare          849 non-null    float64
#  9   cabin         191 non-null    str
#  10  embarked      849 non-null    str
#  11  boat          308 non-null    str
#  12  body          73 non-null     float64
#  13  home.dest     464 non-null    str
#  14  survived      850 non-null    int64
# dtypes: float64(3), int64(5), str(7)
# memory usage: 99.7 KB

# %% [markdown]
# ``Checking of Null values``

# %%
sns.heatmap(final_df.isnull())
# Out:
# <Axes: >

# %%
missing = pd.DataFrame({
    'Missing_Count': final_df.isna().sum(),
    'Missing_Percentage': final_df.isna().mean() * 100
})

print(missing)
# Out:
#               Missing_Count  Missing_Percentage
# passenger_id              0            0.000000
# pclass                    0            0.000000
# name                      0            0.000000
# sex                       0            0.000000
# age                     174           20.470588
# sibsp                     0            0.000000
# parch                     0            0.000000
# ticket                    0            0.000000
# fare                      1            0.117647
# cabin                   659           77.529412
# embarked                  1            0.117647
# boat                    542           63.764706
# body                    777           91.411765
# home.dest               386           45.411765
# survived                  0            0.000000

# %% [markdown]
# ``Observation``
# * Age contains missing value percentage is 20.47 %
# * Cabin contains missing value percentage is 77.52 %
# * Boat contains missing value percentage is 63.76 %
# * Body contains missing value percentage is 91.41 %
# * home.dest contains missing value percentage is 45.41 %

# %%
final_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   name          850 non-null    str
#  3   sex           850 non-null    str
#  4   age           676 non-null    float64
#  5   sibsp         850 non-null    int64
#  6   parch         850 non-null    int64
#  7   ticket        850 non-null    str
#  8   fare          849 non-null    float64
#  9   cabin         191 non-null    str
#  10  embarked      849 non-null    str
#  11  boat          308 non-null    str
#  12  body          73 non-null     float64
#  13  home.dest     464 non-null    str
#  14  survived      850 non-null    int64
# dtypes: float64(3), int64(5), str(7)
# memory usage: 99.7 KB

# %%
final_df.shape
# Out:
# (850, 15)

# %%
print(final_df[final_df['age'].isna()])
print(final_df[final_df['cabin'].isna()])
print(final_df[final_df['boat'].isna()])
print(final_df[final_df['body'].isna()])
# Out:
#      passenger_id  pclass                                    name     sex  \
# 0            1216       3                      Smyth, Miss. Julia  female
# 17           1003       3                      McCoy, Mr. Bernard    male
# 21           1030       3                        Moran, Mr. James    male
# 28            775       3                     Doharr, Mr. Tannous    male
# 30             15       1                     Baumann, Mr. John D    male
# ..            ...     ...                                     ...     ...
# 814          1095       3          O'Sullivan, Miss. Bridget Mary  female
# 820          1167       3                    Sadlier, Mr. Matthew    male
# 821          1123       3  Peter, Mrs. Catherine (Catherine Rizk)  female
# 828          1245       3         Thomson, Mr. Alexander Morrison    male
# 836           107       1    Flegenheim, Mrs. Alfred (Antoinette)  female
#
#      age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# ...

# %%
final_df.describe()
# Out:
#        passenger_id     pclass         age       sibsp       parch  \
# count    850.000000  850.00000  676.000000  850.000000  850.000000
# mean     662.816471    2.32000   29.519847    0.522353    0.382353
# std      380.751936    0.83853   14.562243    1.112132    0.879511
# min        1.000000    1.00000    0.166700    0.000000    0.000000
# 25%      332.250000    2.00000   20.000000    0.000000    0.000000
# 50%      676.500000    3.00000   28.000000    0.000000    0.000000
# 75%      992.250000    3.00000   37.000000    1.000000    0.000000
# max     1307.000000    3.00000   80.000000    8.000000    9.000000
#
#              fare        body    survived
# count  849.000000   73.000000  850.000000
# mean    34.012701  165.821918    0.368235
# std     53.705779   99.068487    0.482610
# min      0.000000    4.000000    0.000000
# 25%      7.895800   75.000000    0.000000
# 50%     14.108300  166.000000    0.000000
# 75%     31.000000  260.000000    1.000000
# ...

# %% [markdown]
# ``performing one-hot encoding``

# %%
print(final_df['sex'].unique())
print(final_df['sex'].value_counts(dropna= False))
# Out:
# <StringArray>
# ['female', 'male']
# Length: 2, dtype: str
# sex
# male      551
# female    299
# Name: count, dtype: int64

# %%
pd.get_dummies(final_df['sex'], drop_first=1)
# Out:
#       male
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# ..     ...
# 845   True
# 846   True
# 847  False
# 848  False
# 849   True
#
# [850 rows x 1 columns]

# %%
FM = pd.get_dummies(final_df['sex'], dtype=int)

# %%
final_df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
final_df['sex'] = final_df['sex'].map({'female':0, 'male':1})

# %%
final_df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#    sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0    0   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    1  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2    0  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3    0  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    1  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# 0                       NaN         1
# ...

# %%
final_df['survived'].value_counts()
# Out:
# survived
# 0    537
# 1    313
# Name: count, dtype: int64

# %% [markdown]
# ``Observation``
# * 537 people did not survived out of 850.
# * 313 people survived out of 850.

# %%
pd.crosstab(final_df['sex'],final_df['survived'], normalize='index')
# Out:
# survived         0         1
# sex
# 0         0.297659  0.702341
# 1         0.813067  0.186933

# %%
pd.crosstab(final_df['pclass'],final_df['survived'], normalize='index')
# Out:
# survived         0         1
# pclass
# 1         0.393204  0.606796
# 2         0.542169  0.457831
# 3         0.765690  0.234310

# %%
final_df['age'].describe()
final_df['age'].isnull().sum()
# Out:
# np.int64(174)

# %%
sns.boxplot(data=final_df, x='survived',  y='age' )
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.barplot(
            data=final_df, 
            x='sex', 
            y='survived', 
            hue = 'sex',
            palette={0:'tab:blue',1:'tab:red'},
            legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(data=final_df, x = 'survived', y = 'pclass')
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.histplot(final_df['fare'], kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
final_df['fare'].isnull().sum()
# Out:
# np.int64(1)

# %%
final_df.head(5)
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#    sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0    0   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    1  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2    0  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3    0  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    1  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# 0                       NaN         1
# ...

# %%
pd.crosstab(final_df['sibsp'],final_df['survived'], normalize='index')
# Out:
# survived         0         1
# sibsp
# 0         0.666667  0.333333
# 1         0.497653  0.502347
# 2         0.560000  0.440000
# 3         0.833333  0.166667
# 4         0.857143  0.142857
# 5         1.000000  0.000000
# 8         1.000000  0.000000

# %%
pd.crosstab(final_df['parch'],final_df['survived'], normalize='index')
# Out:
# survived         0         1
# parch
# 0         0.672811  0.327189
# 1         0.442478  0.557522
# 2         0.527778  0.472222
# 3         0.333333  0.666667
# 4         0.800000  0.200000
# 5         1.000000  0.000000
# 6         1.000000  0.000000
# 9         1.000000  0.000000

# %%
pd.crosstab(final_df['embarked'],final_df['survived'], normalize='index')
# Out:
# survived         0         1
# embarked
# C         0.482955  0.517045
# Q         0.654762  0.345238
# S         0.674024  0.325976

# %%
final_df['embarked'].unique()
# Out:
# <StringArray>
# ['Q', 'S', 'C', nan]
# Length: 4, dtype: str

# %%
final_df['embarked_S'] = final_df['embarked'].replace('Q',0).replace('C',0).replace('S',1)
final_df['embarked_Q'] = final_df['embarked'].replace('C',0).replace('S',0).replace('Q',1)
final_df['embarked_C'] = final_df['embarked'].replace('S',0).replace('Q',0).replace('C',1)

# %%
final_df=final_df.drop('embarked', axis=1)

# %%
final_df.head(5)
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#    sex   age  sibsp  parch  ticket     fare cabin boat  body  \
# 0    0   NaN      0      0  335432   7.7333   NaN   13   NaN
# 1    1  38.0      0      0  315089   8.6625   NaN  NaN   NaN
# 2    0  30.0      1      1  345773  24.1500   NaN  NaN   NaN
# 3    0  54.0      1      3   29105  23.0000   NaN    4   NaN
# 4    1  40.0      0      0   28221  13.0000   NaN  NaN   NaN
#
#                   home.dest  survived embarked_S embarked_Q embarked_C
# 0                       NaN         1          0          1          0
# ...

# %%
final_df['body'].isnull().sum()
# Out:
# np.int64(777)

# %%
final_df.nunique()
# Out:
# passenger_id    850
# pclass            3
# name            849
# sex               2
# age              88
# sibsp             7
# parch             8
# ticket          660
# fare            236
# cabin           135
# boat             26
# body             73
# home.dest       272
# survived          2
# embarked_S        2
# embarked_Q        2
# embarked_C        2
# dtype: int64

# %%
for col in ['age', 'fare']:
    sns.boxplot(data=final_df, x=col)
    plt.title(col)
    plt.show()

# %%
final_df['family_size'] = final_df['parch']+final_df['sibsp']+1

# %%
final_df['isalone'] = (final_df['family_size']==1).astype(int)

# %%
# final_df.drop('sibsp', axis=1, inplace=True)
# final_df.drop('parch', axis=1, inplace=True)

# %%
final_df = final_df.drop(columns = ['name', 'passenger_id','body','boat','home.dest','cabin','ticket'])

# %% [markdown]
# ``Observation``
# * `name`, `passenger_id`, `body`, `boat`, `home.dest`, `cabin` all of them containing the either string vales or large amount of null values.

# %%
final_df.head()
# Out:
#    pclass  sex   age  sibsp  parch     fare  survived embarked_S embarked_Q  \
# 0       3    0   NaN      0      0   7.7333         1          0          1
# 1       3    1  38.0      0      0   8.6625         0          1          0
# 2       3    0  30.0      1      1  24.1500         0          1          0
# 3       2    0  54.0      1      3  23.0000         1          1          0
# 4       2    1  40.0      0      0  13.0000         0          1          0
#
#   embarked_C  family_size  isalone
# 0          0            1        1
# 1          0            1        1
# 2          0            3        0
# 3          0            5        0
# 4          0            1        1

# %% [markdown]
# ``Seperating Features and Target``

# %% [markdown]
# ``Split the data``

# %%
from sklearn.model_selection import train_test_split

x = final_df.drop('survived', axis=1)
y = final_df['survived']

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
print("X_train:", x_train.shape)
print("X_test :", x_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (680, 11)
# X_test : (170, 11)
# y_train: (680,)
# y_test : (170,)

# %%
print("Original:")
print(y.value_counts(normalize=True))

print("\nTraining:")
print(y_train.value_counts(normalize=True))

print("\nTesting:")
print(y_test.value_counts(normalize=True))
# Out:
# Original:
# survived
# 0    0.631765
# 1    0.368235
# Name: proportion, dtype: float64
#
# Training:
# survived
# 0    0.632353
# 1    0.367647
# Name: proportion, dtype: float64
#
# Testing:
# survived
# 0    0.629412
# 1    0.370588
# Name: proportion, dtype: float64

# %% [markdown]
# ``Scalling``

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
